# %% [markdown]
# # Systematic Literature Review DX in Shipping - Thematic Analysis

# %%
#!pip install spacy

# %%
#!python -m spacy download en_core_web_md

# %%
import pandas as pd
import matplotlib.pyplot as plt
import json
import numpy as np
from collections import Counter

import spacy
from spacy.lang.en.stop_words import STOP_WORDS
from spacy.tokens import DocBin

from gensim import corpora
from gensim.models import LdaModel
from sklearn.feature_extraction.text import TfidfVectorizer

from transformers import BertTokenizer, BertModel
import torch
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

# %%
#import numpy as np
#print(hasattr(np, 'typing'))

# %%
# This cell is useful to check columns in the db. To be used only after having loaded the pandas df
substring = 'abstract'
# List all column names containing the substring using list comprehension
matching_columns = [k for k in lit.columns if substring in k]
print(matching_columns)
#lit['abstract_inverted_index']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 4
#       2 substring = 'abstract'
#       3 # List all column names containing the substring using list comprehension
# ----> 4 matching_columns = [k for k in lit.columns if substring in k]
#       5 print(matching_columns)
#
# NameError: name 'lit' is not defined

# %% [markdown]
# ## Read the DB in

# %%
# Read in the file
#lit = pd.read_csv('C:/projects/dx_in_shipping/openalex_data_final.csv')
lit = pd.read_csv('./openalex_data.csv',low_memory=False)

# %%
print(lit.count())
# Out:
# id                                              2293
# doi                                             2324
# title                                           2290
# display_name                                    2290
# publication_year                                2293
#                                                 ...
# abstract_inverted_index_filter.The_0               1
# abstract_inverted_index_connectivity.Smart_0       1
# abstract_inverted_index_costefficiency,_0          1
# abstract_inverted_index_trade.This_0               1
# abstract_inverted_index_remotely-piloted)_0        1
# Length: 56322, dtype: int64

# %%
lit.head(5)
# Out:
#                                  id  \
# 0  https://openalex.org/W4401344941
# 1  https://openalex.org/W4402480811
# 2  https://openalex.org/W4402458914
# 3  https://openalex.org/W4402480954
# 4  https://openalex.org/W4401956356
#
#                                           doi  \
# 0        https://doi.org/10.1155/2024/5225558
# 1      https://doi.org/10.12716/1001.18.03.12
# 2  https://doi.org/10.1186/s13634-024-01182-8
# 3      https://doi.org/10.12716/1001.18.03.19
# 4    https://doi.org/10.3390/agronomy14091932
#
#                                                title  \
# 0  Predictive Analysis of Maritime Congestion Usi...
# 1  VerifAI: Framework for Functional Verification...
# 2  Emerging trends in signal processing and machi...
# 3  Effectiveness of Problem-based Learning (PBL) ...
# 4  Enhancing Leafy Greens’ Production: Nutrient F...
#
#                                         display_name  publication_year  \
# 0  Predictive Analysis of Maritime Congestion Usi...            2024.0
# 1  VerifAI: Framework for Functional Verification...            2024.0
# 2  Emerging trends in signal processing and machi...            2024.0
# 3  Effectiveness of Problem-based Learning (PBL) ...            2024.0
# 4  Enhancing Leafy Greens’ Production: Nutrient F...            2024.0
#
#   publication_date                      ids_openalex  \
# 0       2024-01-01  https://openalex.org/W4401344941
# 1       2024-01-01  https://openalex.org/W4402480811
# 2       2024-09-11  https://openalex.org/W4402458914
# 3       2024-01-01  https://openalex.org/W4402480954
# 4       2024-08-28  https://openalex.org/W4401956356
#
#                                       ids_doi language primary_location_is_oa  \
# 0        https://doi.org/10.1155/2024/5225558       en                   True
# 1      https://doi.org/10.12716/1001.18.03.12       en                   True
# 2  https://doi.org/10.1186/s13634-024-01182-8       en                   True
# 3      https://doi.org/10.12716/1001.18.03.19       en                   True
# 4    https://doi.org/10.3390/agronomy14091932       en                   True
#
#    ... abstract_inverted_index_PMBM_1  \
# 0  ...                            NaN
# 1  ...                            NaN
# 2  ...                            NaN
# 3  ...                            NaN
# 4  ...                            NaN
#
#   abstract_inverted_index_configurations.The_0  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#   abstract_inverted_index_available.The_0 abstract_inverted_index_shown_1  \
# 0                                     NaN                             NaN
# 1                                     NaN                             NaN
# 2                                     NaN                             NaN
# 3                                     NaN                             NaN
# 4                                     NaN                             NaN
#
#   abstract_inverted_index_applications.For_0  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   abstract_inverted_index_filter.The_0  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#   abstract_inverted_index_connectivity.Smart_0  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#   abstract_inverted_index_costefficiency,_0  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   abstract_inverted_index_trade.This_0  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#   abstract_inverted_index_remotely-piloted)_0
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
# [5 rows x 56322 columns]

# %% [markdown]
# ## Thematic analysis

# %%
# Load spaCy's English tokenizer
nlp = spacy.load('en_core_web_md')

def create_abstract(row, abs_colnames):
    abstract_words = []

    # For each of them, we split the 'abstract_inverted_index_ xxxxxx _N' and we take only the xxxxxx
    for aword in abs_colnames:
        if not pd.isnull(row[aword]):
            asplit = aword.split('_')
            if (len(asplit) > 3):
                abstract_words.append(aword.split('_')[3])
    return ' '.join(abstract_words)

# Preprocess a column (e.g., 'abstract' or 'title') in the dataset
def preprocess_text(text):
    doc = nlp(text)
    tokens = [token.lemma_ for token in doc if token.is_alpha and token.text not in STOP_WORDS]
    return " ".join(tokens)

# %%
# In Open Alex we get the abstract as inverted index. Our own notebooks, translates values in column names
# For example: abstract_inverted_index_maritime_2 here the word we want is maritime.

# We extract all columns matching the abstract_inverted_index
abstract_words = []
substring = 'abstract_inverted_index'
# List all column names containing the substring using list comprehension
matching_columns = [k for k in lit.columns if substring in k]
#print(matching_columns)

lit['reconstructed_abstract'] = lit.apply(lambda row: create_abstract(row, matching_columns), axis=1)

# %%
# Apply preprocessing to the relevant column (e.g., 'title' and 'abstract')
lit['cleaned_abstract'] = lit['reconstructed_abstract'].apply(preprocess_text)  # or 'title', depending on your focus

# %%
lit['cleaned_abstract']

# %%
# Detect Topics

# Load pre-trained BERT model and tokenizer from Hugging Face
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertModel.from_pretrained('bert-base-uncased')

# Function to obtain the BERT embeddings
def get_bert_embeddings(texts):
    inputs = tokenizer(texts, padding=True, truncation=True, return_tensors="pt")
    with torch.no_grad():
        outputs = model(**inputs)
    
    # Extract the embeddings of the [CLS] token (index 0)
    embeddings = outputs.last_hidden_state[:, 0, :]
    
    return embeddings.numpy()

# Function to reduce dimensions using PCA
def reduce_dimensions(embeddings, n_components=50):
    pca = PCA(n_components=n_components)
    reduced_embeddings = pca.fit_transform(embeddings)
    
    return reduced_embeddings

# Perform KMeans clustering
def cluster_topics(embeddings, n_clusters=5):
    kmeans = KMeans(n_clusters=n_clusters, random_state=42)
    kmeans.fit(embeddings)
    return kmeans.labels_, kmeans.cluster_centers_

# Final function
def find_topics(row):
    # Step 1: Get BERT embeddings for the texts
    embeddings = get_bert_embeddings(row['cleaned_abstract'])    
    # Step 2: Reduce dimensions (optional, but can improve clustering performance)
    reduced_embeddings = reduce_dimensions(embeddings, n_components=50)
    # Step 3: Cluster topics using KMeans
    labels, centers = cluster_topics(reduced_embeddings, n_clusters=3)
    return labels, centers

lit['topics_labels'], lit['topics_centers'] = lit.apply(lambda row: find_topics(row), axis=1)

# # Print out the topics and the corresponding texts
# for i in range(3):
#     print(f"\nTopic {i+1}:")
#     for j, text in enumerate(texts):
#         if labels[j] == i:
#             print(f" - {text}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[54], line 4
#       1 # Detect Topics
#       2
#       3 # Create the BERTopic model
# ----> 4 topic_model = BERTopic(language='english')
#       6 # Fit the model on your data
#       7 topics, _ = topic_model.fit_transform(lit['cleaned_abstract'])
#
# NameError: name 'BERTopic' is not defined

# %%
# 4. Countries

# find all useful columns
substring = '_country_code'
matching_columns = [k for k in lit.columns if substring in k]

# Step 1: Collect all institution names from the specified columns
countryCodelist = lit[matching_columns].values.ravel()  # Flatten to a 1D array of institution names

# Step 2: Remove any NaN values from the list if they exist
countryCodelist = [inst for inst in countryCodelist if pd.notna(inst)]

# Step 3: Count the frequency of each institution name
countryCodecounts = Counter(countryCodelist)

# Step 4: Convert the counts to a DataFrame, sort by count in descending order
countryCodedf = pd.DataFrame(countryCodecounts.items(), columns=['inst', 'Count']).sort_values(by='Count', ascending=False).reset_index(drop=True)

# Display the result
print(countryCodedf)

# Calculate the normal and cumulative percentage of appearances
total_count = countryCodedf['Count'].sum()
countryCodedf['Cumulative Percentage'] = countryCodedf['Count'].cumsum() / total_count * 100

# Calculate individual percentage for each inst
countryCodedf['Percentage'] = countryCodedf['Count'] / total_count * 100

# Now select the top 20 insts for plotting
top_20_insts_df = countryCodedf.head(20)

# Plot the cumulative percentage bar plot for the top 20 insts only
fig, ax = plt.subplots(figsize=(10, 6))
ax.bar(top_20_insts_df['inst'], top_20_insts_df['Count'], color='skyblue', label="Individual Count")
ax.plot(top_20_insts_df['inst'], top_20_insts_df['Cumulative Percentage'], color='orange', marker='o', label="Cumulative Percentage")

# Highlight the top inst’s contribution
top_countryCodepercentage = countryCodedf['Cumulative Percentage'].iloc[0]
ax.axhline(y=top_countryCodepercentage, color='red', linestyle='--', label=f"Top inst: {top_countryCodepercentage:.1f}%")

# Labels and Title
plt.xticks(rotation=90)
plt.xlabel("Country")
plt.ylabel("Count")
plt.title("Top 20 Countries Contribution and Cumulative Percentage (over Full Total)")
plt.legend()
plt.tight_layout()
plt.show()

print(top_20_insts_df)
# Out:
#    inst  Count
# 0    CN   2457
# 1    US    767
# 2    GB    466
# 3    NO    368
# 4    KR    353
# ..  ...    ...
# 87   TG      1
# 88   KE      1
# 89   GH      1
# 90   TN      1
# 91   MM      1
#
# [92 rows x 2 columns]
#    inst  Count  Cumulative Percentage  Percentage
# 0    CN   2457              25.920456   25.920456
# 1    US    767              34.012027    8.091571
# 2    GB    466              38.928157    4.916130
# 3    NO    368              42.810423    3.882266
# 4    KR    353              46.534445    3.724022
# 5    ES    315              49.857580    3.323135
# 6    IT    300              53.022471    3.164891
# 7    DE    257              55.733727    2.711256
# 8    CA    257              58.444984    2.711256
# 9    GR    255              61.135141    2.690157
# 10   AU    249              63.762000    2.626859
# 11   SG    233              66.220065    2.458065
# 12   IN    212              68.456588    2.236523
# 13   FI    183              70.387172    1.930583
# 14   ID    162              72.096213    1.709041
# 15   FR    161              73.794704    1.698491
# 16   HR    148              75.356050    1.561346
# 17   BR    132              76.748602    1.392552
# 18   SE    125              78.067307    1.318705
# 19   PL    123              79.364912    1.297605

# %%
# 5. Citation counts

# Assuming your dataset is a DataFrame called lit_df with 'title' and 'citation_normalized_percentile'
# Sort the dataset by 'cited_by_count' but only include rows where 'cited_by_count' is not NaN
top_20_articles_cited = lit[lit['cited_by_count'].notna()].sort_values(by='cited_by_count', ascending=False).head(20)


# Select only the title and citation_normalized_percentile columns for display
top_20_articles_report = top_20_articles[['title', 'doi', 'cited_by_count']]

# Display the top 20 articles
print(top_20_articles_report)

# average_citations = df['citations'].mean()
# total_citations = df['citations'].sum()
# print("\nCitation statistics:")
# print(f"Total citations: {total_citations}")
# print(f"Average citations per publication: {average_citations:.2f}")
# Out:
#                                                   title  \
# 1277  Blockchain technology in supply chain operatio...
# 2052      Data Security in the World of Cloud Computing
# 1139              Safety in shipping: The human element
# 1111          From Predictive to Prescriptive Analytics
# 1257  A modelling system for the exhaust emissions o...
# 2102  6G Wireless Channel Measurements and Models: T...
# 355   How big data enriches maritime research – a cr...
# 540   Maritime shipping digitalization: Blockchain-b...
# 774   Energy storage emerging: A perspective from th...
# 2299  Internet of Underwater Things and Big Marine D...
# 1247  Global supply chain and port/terminal: integra...
# 2179  Collaborative Multi-Robot Search and Rescue: P...
# 567   Big data and artificial intelligence in the ma...
# 1230  AN EMPIRICAL ANALYSIS OF FACTORS INFLUENCING I...
# 1241  The Ship Domain – A Criterion of Navigational ...
# 1275  Augmenting the algorithm: Emerging human-in-th...
# 1610  The shift to 6G communications: vision and req...
# 912   Smart contract-based approach for efficient sh...
# 1530  Digital transformation in maritime ports: anal...
# 2300  A Survey on Technologies, Standards and Open C...
#
#                                                 doi  cited_by_count
# 1277      https://doi.org/10.1016/j.tre.2020.102067           914.0
# 2052            https://doi.org/10.1109/msp.2009.87           775.0
# 1139      https://doi.org/10.1016/j.jsr.2006.04.007           602.0
# 1111         https://doi.org/10.1287/mnsc.2018.3253           420.0
# 1257        https://doi.org/10.5194/acp-9-9209-2009           396.0
# 2102       https://doi.org/10.1109/mvt.2020.3018436           360.0
# 355   https://doi.org/10.1080/01441647.2019.1649315           285.0
# 540       https://doi.org/10.1016/j.tre.2019.09.020           270.0
# 774         https://doi.org/10.1073/pnas.1821672117           259.0
# 2299     https://doi.org/10.1109/comst.2021.3053118           256.0
# 1247      https://doi.org/10.1080/03088830701848953           247.0
# 2179    https://doi.org/10.1109/access.2020.3030190           245.0
# 567   https://doi.org/10.1080/03088839.2020.1788731           244.0
# 1230      https://doi.org/10.1142/s0219622011004543           236.0
# 1241      https://doi.org/10.1017/s0373463308005018           223.0
# 1275     https://doi.org/10.1016/j.jsis.2020.101614           220.0
# 1610     https://doi.org/10.1186/s13673-020-00258-2           204.0
# 912       https://doi.org/10.1016/j.cie.2019.07.022           201.0
# 1530      https://doi.org/10.1007/s11066-017-9122-x           201.0
# 2300     https://doi.org/10.1109/comst.2021.3078433           199.0
